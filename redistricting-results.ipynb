# %%
import json

# %%
# read color samples
with open('data/samples3.json', 'r') as read_file:
    color_data = json.load(read_file)
color_data
# Out:
# {'num_samples': 30,
#  'num_iterations': 3000,
#  'beta_type': 'linear',
#  'start_beta': 5e-06,
#  'end_beta': 5.0,
#  'color_list': [{'1462': 14,
#    '1461': 14,
#    '1460': 14,
#    '1459': 14,
#    '2306': 4,
#    '1458': 14,
#    '2305': 4,
#    '1457': 14,
#    '2304': 4,
#    '2303': 7,
#    '1456': 14,
#    '2302': 7,
#    '1455': 14,
#    '1454': 14,
#    '2301': 7,
#    '2300': 9,
#    '1453': 14,
#    '1452': 14,
#    '2309': 4,
#    '2308': 4,
#    '2307': 4,
#    '1473': 14,
#    '2320': 4,
#    '1472': 14,
#    '1471': 14,
#    '1470': 14,
#    '2317': 4,
#    '0': 12,
#    '2316': 4,
#    '1': 12,
#    '1469': 14,
#    '2315': 4,
#    '2': 12,
#    '1468': 14,
#    '3': 12,
#    '2314': 4,
#    '1467': 14,
#    '1466': 14,
#    '4': 12,
#    '2313': 4,
#    '1465': 14,
#    '2312': 4,
#    '5': 12,
#    '1464': 14,
#    '2311': 4,
#    '6': 12,
#    '7': 13,
#    '1463': 14,
#    '2310': 4,
#    '8': 12,
#    '9': 12,
#    '2319': 4,
#    '2318': 4,
#    '1000': 8,
# ...

# %%
with open('data/GeorgiaMetadata.json', 'r') as read_file:
    ga_metadata = json.load(read_file)
ga_metadata
# Out:
# {'0': {'ID': 6094217.0,
#   'AREA': 1.86,
#   'DATA': 690.0,
#   'POPULATION': 1013.0,
#   'DISTRICT': '073131',
#   'CTYSOSID': '073131',
#   'PRECINCT_I': '131',
#   'PRECINCT_N': 'JOURNEY COMM. CHURCH',
#   'CTYNUMBER': '36',
#   'COUNTY': '036',
#   'CTYNAME': 'Columbia',
#   'FIPS1': '13073',
#   'FIPS2': '073',
#   'COUNTY_NAM': 'COLUMBIA',
#   'G16PREDCli': 107,
#   'G16PRELJoh': 20,
#   'G16PRERTru': 459,
#   'G16USSDBar': 78,
#   'G16USSLBuc': 23,
#   'G16USSRIsa': 453,
#   'G16PSCLHos': 66,
#   'G16PSCREch': 477,
#   'coloring': 12},
#  '1': {'ID': 6094266.0,
#   'AREA': 1.64,
#   'DATA': 714.0,
#   'POPULATION': 3858.0,
#   'DISTRICT': '073064',
#   'CTYSOSID': '073064',
#   'PRECINCT_I': '064',
#   'PRECINCT_N': 'GRACE BAPTIST CHURCH',
#   'CTYNUMBER': '36',
#   'COUNTY': '036',
#   'CTYNAME': 'Columbia',
#   'FIPS1': '13073',
#   'FIPS2': '073',
#   'COUNTY_NAM': 'COLUMBIA',
#   'G16PREDCli': 767,
#   'G16PRELJoh': 74,
#   'G16PRERTru': 1334,
#   'G16USSDBar': 643,
# ...

# %%
for colors in color_data['color_list']:
    for synthetic_id in colors:
        print(ga_metadata[synthetic_id]['PRECINCT_N'])
# Out:
# CHERRY LOG
# BIG CREEK
# MORGANTON
# NOONTOOTLA
# MILLER GROVE
# SKENIAH
# MCWILLIAMS
# 6A
# SNAPFINGER ROAD S
# ROCKBRIDGE D
# 1A
# ROCKBRIDGE F
# 3A
# 4A
# BT
# HI
# SAMMY MCCLURE MID SC
# MOSES MIDDLE SCHOOL
# FAIRINGTON ELEM
# CROSSROADS
# BETHUNE MIDDLE
# NI
# CANDLER
# GL
# FI
# ES
# EAST LAKE (ATL)
# JOURNEY COMM. CHURCH
# MCNAIR ACADEMY
# GRACE BAPTIST CHURCH
# CARTERS-DOOLITTLE
# FLAT SHOALS ELEM
# GREENBRIER HIGH
# SHUCK PEN
# RIVERSIDE ELEMENTARY
# FLAT SHOALS
# SPRING PLACE
# CARTECAY
# WESLEY METHODIST
# REDAN MIDDLE
# MOBILE
# YOUNG ROAD
# CHRIST CHURCH, PRESBYTERIAN
# COLWELL
# PANOLA WAY ELEM
# GOSPEL WATER BRANCH
# RIVERDALE 12
# TOCCOA
# PANOLA ROAD
# EUBANK/BLANCHARD CTR
# TABERNACLE
# KELLEY LAKE ELEM
# MCNAIR
# PLAIN
# CEDAR GROVE SOUTH
# CENTER POST
# ELLENWOOD
# MOUNTAIN
# CA
# BLACKSTOCK
# TR
# MORROW 1
# CLAIRMONT ROAD
# WOODSTATION
# MEDLOCK
# ARMUCHEE VALLEY
# SCOTT
# CLAIREMONT WEST (DEC)
# MC
# AN
# GLENNWOOD (DEC)
# DG
# WINNONA PARK ELEM (DEC)
# TI
# ...
